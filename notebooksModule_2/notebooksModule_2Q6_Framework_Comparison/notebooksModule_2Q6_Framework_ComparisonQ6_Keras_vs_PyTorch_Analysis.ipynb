# %%
import pandas as pd

results = pd.DataFrame({
    "Framework": ["Keras", "PyTorch"],
    "Accuracy": [0.88, 0.86],
    "Training Speed": ["Fast", "Moderate"],
    "Flexibility": ["Medium", "High"]
})

results
